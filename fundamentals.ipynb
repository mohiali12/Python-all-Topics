# %% [markdown]
# Variables & Datatypes

# %%
first_variable = "123"
b = int(first_variable)
print(b)
print(type(b))

c = float(first_variable)
print(c)
print(type(c))
# Out:
# 123
# <class 'int'>
# 123.0
# <class 'float'>

# %%
a = 1
b = str(a)
print(type(b))
print(b)
# Out:
# <class 'str'>
# 1

# %%
a = b = 1
print(b)
print(a)
# Out:
# 1
# 1

# %%
a,b,c = 1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
a = "My name is"
b = " Mohsin Ali"

c = a + b
print(c)
# Out:
# My name is Mohsin Ali

# %%
first_name = "Mohsin"
last_name = "Ali"
result = first_name+ " " +last_name
print(result)
# Out:
# Mohsin Ali

# %%
a = "Mohsin Ali "

print(a * 3)
# Out:
# Mohsin Ali Mohsin Ali Mohsin Ali

# %%
a = 10
b = 5

print(a+b)
print(a-b)
print(a/b)
print(a*b)
print(a**b)
print(a%b)
# Out:
# 15
# 5
# 2.0
# 50
# 100000
# 0

# %%
a = 10
b = 5

print(a>b)
print(a<b)
print(a==b)
print(a<=b)
print(a>=b)
# Out:
# True
# False
# False
# False
# True

# %%
a = input("Enter First name")
b = input("Last Name")

print(a +" "+ b)
# Out:
# Mohsin Ali

# %%
num = int(input("Enter a number"))
num2 = int(input("Enter second number"))

sum = num + num2
print("sum is", sum)
# Out:
# sum is 10

# %%
a = input("Enter name")
b = input("Enter age")


c = a+ " "+b

print(c)
# Out:
# My name is Mohsin 23

# %%
a = int(input("enter a number "))
if a%2==0:
    print("This nunber is even")
else:
    print("This number is odd")
# Out:
# This number is odd

# %%
a = int(input("Enter a number"))

print("number is this", a)
# Out:
# number is this 6

# %%
a = int(input("Enter a number"))
b = int(input("Enter second number"))

result = a + b
print(result)
# Out:
# 10

# %%
a = input("Enter name")
b = int(input("Enter age"))

print(f"My name is {a} and my age is {b} ")
# Out:
# My name is Mohsin and my age is 23

# %%
price = float(input("Enter price : "))
quantity = int(input("Enter quantity : "))

result = price * quantity
print("Total result is: ", result)
# Out:
# Total result is:  400.0

# %%
a = input()
print("You entered : ", a)
# Out:
# You entered :  6

# %%
a = int(input("Enter a number"))
b = int(input("Enter second number"))


sum = a+b
sub = a-b
divide = a/b
multi = a* b

print(f"Sum is {sum} subtract is {sub} divide is {divide} mulitply is {multi}")
# Out:
# Sum is 15 subtract is 5 divide is 2.0 mulitply is 50

# %%
a = int(input("Enter a number"))
b = int(input("Enter second number"))
c = int(input("Enter third number"))

sum = a+b+c
average = sum /3

print(average)
# Out:
# 2.0

# %%
name = input("Enter name")
city = input("Enter city name")

print(f"My name is {name} and i live in {city}")
# Out:
# My name is Mohsin Ali and i live in Multan

# %%
c = int(input("Enter celcius value"))

F = (c*9/5) +32
print("Convert celcius into fahrenheit",F)
# Out:
# Convert celcius into fahrenheit 118.4

# %%
a = int(input("Enter chemistry marks"))
b = int(input("Enter physics marks"))
c = int(input("Enter math marks"))

sum = a+b+c
average = sum /3
if average >=50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
a = int(input("Enter a number"))
if a>=0:
    print("Positive number")
else:
    print("Negative number")
# Out:
# Positive number

# %%
a = int(input("Enter marks"))

if a>=90:
    print("A")
elif a>=76:
    print("B")
elif a>=50:
    print("C")
else:
    print("Fail")
# Out:
# B

# %%
a = int(input("Enter a number"))
b = int(input("Enter second number"))

if a>b:
    print('A is greater')
else:
    print("B is greater")
# Out:
# A is greater

# %%
a = int(input("Enter a number"))
b = int(input("Enter second number"))
c = int(input("Enter third number"))

if a>b & a>c:
    print("A is greater")
elif b>a &b>c:
    print("B is greater")
else:
    print("C is greater")
# Out:
# C is greater

# %%
a = input("Enter a character")

if a in "aiou":
    print("This is vowle")
else:
    print("consonant")
# Out:
# This is vowle

# %%
username = input("Enter username")
passward = input("Enter passward")

if username == "mohi12" and passward == "112233":
    print("Login successfull")
else:
    print("Try again")
# Out:
# Login successfull

# %%
amount = float(input("Enter amount"))
if amount >1000:
    discount = amount * 0.1
    print("Discount", discount)
else:
    print("No discount")
# Out:
# Discount 1002.0

# %%
a = int(input("Enter a number"))

if a%5==0:
    print("Divisible")

else:
    print("Not divisible")
# Out:
# Divisible

# %%
age = int(input("Enter age"))

if age<=17:
    print("Child")
elif age>=18 and age<=50:
    print("Adult")
else:
    print("Old")
# Out:
# Old

# %%
passward = input("Enter passward")

if len(passward) >=8:
    print("Greater than 8")
else:
    print("Not greater")
# Out:
# Greater than 8
